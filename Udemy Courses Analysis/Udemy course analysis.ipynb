# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Reading csv file**

# %%
df = pd.read_csv('Udemy Courses.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
df.shape
# Out:
# (3682, 11)

# %% [markdown]
# **For what all different subjects udemy is offering course?**

# %%
df['subject'].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# **Which Subject has maximum no of courses?**

# %%
df['subject'].value_counts().idxmax()
# Out:
# 'Web Development'

# %%
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# Web development subject has the highest no of courses offered i.e, 1200

# %% [markdown]
# **Show all the courses which are free of cost**

# %%
df[df['is_paid'] == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %% [markdown]
# **Show all the courses which are paid**

# %%
df[df['is_paid'] == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# **Which are the top selling courses?**

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.sort_values('num_subscribers', ascending = False)[['course_title','num_subscribers']].head(5)
# Out:
#                                            course_title  num_subscribers
# 2230               Learn HTML5 Programming From Scratch           268923
# 776                      Coding for Entrepreneurs Basic           161029
# 3385                         The Web Developer Bootcamp           121584
# 640   Build Your First Website in 1 Week with HTML5 ...           120291
# 3316              The Complete Web Developer Course 2.0           114512

# %% [markdown]
# **Which are the least selling courses?**

# %%
df.sort_values('num_subscribers', ascending = True)[['course_title','num_subscribers']].head(5)
# Out:
#                                       course_title  num_subscribers
# 649                  Building a Balanced Scorecard                0
# 3259     The Cash Flow Statement - An Introduction                0
# 3261               The Complete Adobe Spark Course                0
# 910   Create Beautiful Image Maps for Your Website                0
# 3328   The Cuckoo Strategy to get European Funding                0

# %% [markdown]
# **Show all the courses of Graphic design where the price is below 100**

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df['subject'].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
df['price'] = df['price'].replace('Free',0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
df['price'] = df['price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   int32
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int32(1), int64(4), object(5)
# memory usage: 277.0+ KB

# %%
df[(df['subject'] == 'Graphic Design') & (df['price'] < 100)]['course_title']
# Out:
# 8       :::Beginners Guide To Creating Amazing Images ...
# 20      15  Motion Graphic Elements in After Effect (S...
# 35      3DS MAX - Learn 3Ds MAX tutorial for Beginners...
# 39                         48 Logo Designs and Techniques
# 52           8 Stunden professionelles Cinema 4D Training
#                               ...
# 3568                   Web Elements Design With Photoshop
# 3588    Whiteboard Animation, Beginner To Expert - In ...
# 3639           Wordpress: Comment utiliser le thème FABLE
# 3671    YOU can Draw, Shade and Paint a Mixed Media Gi...
# 3681                  Zombie Apocalypse Photoshop Actions
# Name: course_title, Length: 485, dtype: object

# %% [markdown]
# **List out all the couses which are related with python**

# %%
df[df['course_title'].str.contains('Python')]['course_title']
# Out:
# 216     Advanced Scalable Python Web Development Using...
# 777     Coding for Entrepreneurs: Learn Python, Django...
# 814     Complete Python Web Course: Build 8 Python Web...
# 842     Core: A Web App Reference Guide for Django, Py...
# 1400    Fun and creative web engineering with Python a...
# 1932              Introduction to QGIS Python Programming
# 1969            Investment Portfolio Analysis with Python
# 2294          Learn Python and Django: Payment Processing
# 2295              Learn Python Django - A Hands-On Course
# 2341    Learn to code in Python and learn Adobe Photos...
# 2906      Professional Python Web Development Using Flask
# 2908    Professional RESTful API Design using Python F...
# 2929                        Projects in Django and Python
# 2952    Python Algo Stock Trading: Automate Your Trading!
# 2953           Python Algo Trading: FX Trading with Oanda
# 2954     Python Algo Trading: Sentiment Trading with News
# ...

# %% [markdown]
# **what are the courses published in 2015**

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
# 3     75              850            3            43  Intermediate Level
# 4     75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   int32
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int32(1), int64(4), object(5)
# memory usage: 277.0+ KB

# %%
df['published_timestamp'] = pd.to_datetime(df.published_timestamp)

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
# 3     75              850            3            43  Intermediate Level
# 4     75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
df[df['published_timestamp'].dt.year == 2015]['course_title']
# Out:
# 10      1 - Concepts of Statistics For Beginners Step ...
# 16            10 Numbers Every Business Owner Should Know
# 19      101 Blues riffs - learn how the harmonica supe...
# 23      16 Guitar Chords to Jam With - (Beginner - Int...
# 26          2 Easy Steps To Investment And Avoiding Traps
#                               ...
# 3675                           Your First Course on Piano
# 3676    Your First Successful Forex Trades - With Case...
# 3677    Your Own Site in 45 Min: The Complete Wordpres...
# 3678      Your Second Course on Piano: Two Handed Playing
# 3679    Zend Framework 2: Learn the PHP framework ZF2 ...
# Name: course_title, Length: 1014, dtype: object

# %% [markdown]
# **What is the max level of subscribers for each level of course?**

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
# 3     75              850            3            43  Intermediate Level
# 4     75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level').num_subscribers.max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
